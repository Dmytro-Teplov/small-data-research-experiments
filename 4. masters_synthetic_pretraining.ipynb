# %% [markdown]
# /content/drive/MyDrive/research

# %%
# %pip install thop opencv-python psutil requests matplotlib numpy huggingface_hub

# %%
import sys
sys.path.append('/content/drive/MyDrive/research')

from ultralytics import YOLO
import os
os.chdir('/content/drive/MyDrive/research')
#from drive.MyDrive.research.ultralytics import YOLO

# ---------------- CONFIG ----------------
DATA_YAML_100 = "syntetic_experiments/dataset/data.yaml"

#DATA = [DATA_YAML_100, DATA_YAML_80, DATA_YAML_50, DATA_YAML_30]
#DATA_NOTATIONS = ["100", "80", "50", "30"]

PRETRAINED_MODEL_50N = "experiments/models/custom/n_50.pt"
PRETRAINED_MODEL_50S = "experiments/models/custom/s_50.pt"
PRETRAINED_MODEL_50M = "experiments/models/custom/m_50.pt"
PRETRAINED_MODEL_50L = "experiments/models/custom/l_50.pt"

PRETRAINED_MODELS = [PRETRAINED_MODEL_50S, PRETRAINED_MODEL_50M,
                     PRETRAINED_MODEL_50L]
MDLS = ["L"]
EXP = "4"

#PRETRAINED_MODEL_100_N = "experiments/models/official/yolo12l.pt"
MODEL_N = "yolov12n.yaml"
MODEL_S = "yolov12s.yaml"
MODEL_M = "yolov12m.yaml"
MODEL_L = "yolov12l.yaml"
MODELS = [MODEL_L]

EPOCHS = 150
PATIENCE = 30
BATCH_SIZE = 48
WORKERS = 4
LR = 0.001
FREEZE_BACKBONE = True
# ----------------------------------------
def main():
    # Load YOLO model
    for j, m in enumerate(MODELS):
      model = YOLO(m)
      MDL=MDLS[j]
      results = model.train(
          data=DATA_YAML_100,
          epochs=EPOCHS,
          batch=BATCH_SIZE,
          imgsz=640,          # input image size
          project="/content/syntetic_trained/"+MDL+"/EX_"+EXP+"_F0_A1_"+MDL+"_100", # Changed to local path to avoid Google Drive write issues
          amp=True,
          freeze=False,
          workers=WORKERS,
          patience=PATIENCE,
          seed=43
      )

    print("Training complete! Model weights saved locally in /content/yolo_runs. Remember to copy them to your Google Drive.")

if __name__ == '__main__':
    #import multiprocessing
    #multiprocessing.freeze_support()
    main()
# Out:
# New https://pypi.org/project/ultralytics/8.4.41 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# ...

# %%
# !cp -r /content/syntetic_trained /content/drive/MyDrive/research/syntetic_experiments/syntetic_trained/

# %%
import sys
sys.path.append('/content/drive/MyDrive/research')

from ultralytics import YOLO
import os
os.chdir('/content/drive/MyDrive/research')
#from drive.MyDrive.research.ultralytics import YOLO

# ---------------- CONFIG ----------------
DATA_YAML_100 = "TACO_splits_with_test/Custom_TACO_split_100/data.yaml"
DATA_YAML_80 = "TACO_splits_with_test/Custom_TACO_split_80/data.yaml"
DATA_YAML_50 = "TACO_splits_with_test/Custom_TACO_split_50/data.yaml"
DATA_YAML_30 = "TACO_splits_with_test/Custom_TACO_split_30/data.yaml"
PRETRAINED_MODEL_0 = "yolov12l.yaml"
PRETRAINED_MODEL_100_N = "experiments/models/official/yolo12l.pt"
MDL = "L"
EPOCHS = 200
BATCH_SIZE = 64
WORKERS = 4
LR = 0.001
FREEZE_BACKBONE = True
# ----------------------------------------
def main():
    # Load pretrained YOLO model
    #model = YOLO(PRETRAINED_MODEL_0)
    model2 = YOLO(PRETRAINED_MODEL_100_N)

    #---------------------EX2_F0
    results3 = model2.train(
        data=DATA_YAML_30,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F0_A1_"+MDL+"_30",
        amp=True,
        freeze=False,
        workers=WORKERS,
        lr0=LR
    )
    results4 = model2.train(
        data=DATA_YAML_50,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F0_A1_"+MDL+"_50",
        amp=True,
        freeze=False,
        workers=WORKERS,
        lr0=LR
    )
    results5 = model2.train(
        data=DATA_YAML_80,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F0_A1_"+MDL+"_80", # Changed to local path to avoid Google Drive write issues
        amp=True,
        freeze=False,
        workers=WORKERS,
        lr0=LR
    )
    results6 = model2.train(
        data=DATA_YAML_100,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F0_A1_"+MDL+"_100", # Changed to local path to avoid Google Drive write issues
        amp=True,
        freeze=False,
        workers=WORKERS,
        lr0=LR
    )

    #---------------------EX2_F1
    results3 = model2.train(
        data=DATA_YAML_30,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F1_A1_"+MDL+"_30",
        amp=True,
        freeze=True,
        workers=WORKERS,
        lr0=LR
    )

    results4 = model2.train(
        data=DATA_YAML_50,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F1_A1_"+MDL+"_50",
        amp=True,
        freeze=True,
        workers=WORKERS,
        lr0=LR
    )
    results5 = model2.train(
        data=DATA_YAML_80,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F1_A1_"+MDL+"_80", # Changed to local path to avoid Google Drive write issues
        amp=True,
        freeze=20,
        workers=WORKERS,
        lr0=LR
    )

    results6 = model2.train(
        data=DATA_YAML_100,
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=640,          # input image size
        project="/content/"+MDL+"/EX_2_F1_A1_"+MDL+"_100", # Changed to local path to avoid Google Drive write issues
        amp=True,
        freeze=True,
        workers=WORKERS,
        lr0=LR
    )
    print("Training complete! Model weights saved locally in /content/yolo_runs. Remember to copy them to your Google Drive.")
    # Example of how to copy the results from results5 to Google Drive after training:
    # !mkdir -p /content/drive/MyDrive/research/experiments/M/EX_2_F0_A1_M_80
    # !cp -r /content/yolo_runs/M/EX_2_F0_A1_M_80/train2 /content/drive/MyDrive/research/experiments/M/EX_2_F0_A1_M_80/
    #
    # Example of how to copy the results from results6 to Google Drive after training:
    # !mkdir -p /content/drive/MyDrive/research/experiments/M/EX_2_F0_A1_M_100
    # !cp -r /content/yolo_runs/M/EX_2_F0_A1_M_100/train2 /content/drive/MyDrive/research/experiments/M/EX_2_F0_A1_M_100/

if __name__ == '__main__':
    #import multiprocessing
    #multiprocessing.freeze_support()
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2664/2793379980.py in <cell line: 0>()
#       2 sys.path.append('/content/drive/MyDrive/research')
#       3
# ----> 4 from ultralytics import YOLO
#       5 import os
#       6 os.chdir('/content/drive/MyDrive/research')
#
# /content/drive/MyDrive/research/ultralytics/__init__.py in <module>
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
#      10
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# /content/drive/MyDrive/research/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
#       2
# ----> 3 from .fastsam import FastSAM
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/research')

from ultralytics import YOLO
import os
os.chdir('/content/drive/MyDrive/research')
#from drive.MyDrive.research.ultralytics import YOLO
import time
# ---------------- CONFIG ----------------
VAR="3"
DATA_YAML_100 = f"TACO_5_variations/var{VAR}/subset_100/data.yaml"
DATA_YAML_80 = f"TACO_5_variations/var{VAR}/subset_80/data.yaml"
DATA_YAML_50 = f"TACO_5_variations/var{VAR}/subset_50/data.yaml"
DATA_YAML_30 = f"TACO_5_variations/var{VAR}/subset_30/data.yaml"

DATA = [DATA_YAML_100, DATA_YAML_80, DATA_YAML_50, DATA_YAML_30]
#DATA = [DATA_YAML_100]
#DATA_NOTATIONS = ["100_2", "80", "50", "30"]
DATA_NOTATIONS = ["100", "80", "50", "30"]

PRETRAINED_MODEL_N = "syntetic_experiments/syntetic_trained/models/n.pt"
PRETRAINED_MODEL_S = "syntetic_experiments/syntetic_trained/models/s.pt"
PRETRAINED_MODEL_M = "syntetic_experiments/syntetic_trained/models/m.pt"
PRETRAINED_MODEL_L = "syntetic_experiments/syntetic_trained/models/l.pt"

MDLS = ["N", "S", "M", "L"]
#MDLS = ["L"]
MDLS_low = ["n", "s", "m", "l"]
#PRETR_NOTATIONS = ["10", "30", "50", "80"]
EXP = "9"
EPOCHS = 150
BATCH_SIZE = 64
WORKERS = 4
LR = 0.001
FREEZE_BACKBONE = True
# ----------------------------------------
def main():
    # Load pretrained YOLO model

    modeln = YOLO(PRETRAINED_MODEL_N)
    models = YOLO(PRETRAINED_MODEL_S)
    modelm = YOLO(PRETRAINED_MODEL_M)
    modell = YOLO(PRETRAINED_MODEL_L)
    for i, dataset in enumerate(DATA):
      resultn = modeln.train(
          data=dataset,
          epochs=EPOCHS,
          batch=BATCH_SIZE,
          imgsz=640,          # input image size
          project="/content/variative_synt_experiments/var"+VAR+"_results/N/EX_"+EXP+"_F1_A1_N_"+DATA_NOTATIONS[i],
          amp=True,
          freeze=FREEZE_BACKBONE,
          workers=WORKERS,
          patience=30
      )

      results = models.train(
          data=dataset,
          epochs=EPOCHS,
          batch=BATCH_SIZE,
          imgsz=640,          # input image size
          project="/content/variative_synt_experiments/var"+VAR+"_results/S/EX_"+EXP+"_F1_A1_S_"+DATA_NOTATIONS[i],
          amp=True,
          freeze=FREEZE_BACKBONE,
          workers=WORKERS,
          patience=30
      )

      resultm = modelm.train(
          data=dataset,
          epochs=EPOCHS,
          batch=BATCH_SIZE,
          imgsz=640,          # input image size
          project="/content/variative_synt_experiments/var"+VAR+"_results/M/EX_"+EXP+"_F1_A1_M_"+DATA_NOTATIONS[i],
          amp=True,
          freeze=FREEZE_BACKBONE,
          workers=WORKERS,
          patience=30
      )

      resultl = modell.train(
          data=dataset,
          epochs=EPOCHS,
          batch=BATCH_SIZE,
          imgsz=640,          # input image size
          project="/content/variative_synt_experiments/var"+VAR+"_results/L/EX_"+EXP+"_F1_A1_L_"+DATA_NOTATIONS[i],
          amp=True,
          freeze=FREEZE_BACKBONE,
          workers=WORKERS,
          patience=30
      )
      # !rsync -av /content/variative_synt_experiments/ /content/drive/MyDrive/research/variative_synt_experiments/
      time.sleep(3)

    print("Training complete! Model weights saved locally in /content/yolo_runs. Remember to copy them to your Google Drive.")

if __name__ == '__main__':
    main()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/yolov12/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# FlashAttention is not available on this device. Using scaled_dot_product_attention instead.
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# ...

# %%
# !rsync -av /content/variative_synt_experiments/ /content/drive/MyDrive/research/variative_synt_experiments/
# Out:
# sending incremental file list
# ./
# var3_results/
# var3_results/L/
# var3_results/L/EX_9_F1_A1_L_100/
# var3_results/L/EX_9_F1_A1_L_100/train/
# var3_results/L/EX_9_F1_A1_L_100/train/weights/
# var3_results/L/EX_9_F1_A1_L_30/
# var3_results/L/EX_9_F1_A1_L_30/train/
# var3_results/L/EX_9_F1_A1_L_30/train/weights/
# var3_results/L/EX_9_F1_A1_L_50/
# var3_results/L/EX_9_F1_A1_L_50/train/
# var3_results/L/EX_9_F1_A1_L_50/train/weights/
# var3_results/L/EX_9_F1_A1_L_80/
# var3_results/L/EX_9_F1_A1_L_80/train/
# var3_results/L/EX_9_F1_A1_L_80/train/weights/
# var3_results/M/
# var3_results/M/EX_9_F1_A1_M_100/
# var3_results/M/EX_9_F1_A1_M_100/train/
# var3_results/M/EX_9_F1_A1_M_100/train/weights/
# var3_results/M/EX_9_F1_A1_M_30/
# var3_results/M/EX_9_F1_A1_M_30/train/
# var3_results/M/EX_9_F1_A1_M_30/train/weights/
# var3_results/M/EX_9_F1_A1_M_50/
# var3_results/M/EX_9_F1_A1_M_50/train/
# var3_results/M/EX_9_F1_A1_M_50/train/weights/
# var3_results/M/EX_9_F1_A1_M_80/
# ...
